# %%
import os
os.chdir('/content/drive/MyDrive/EM_sensitivity_0430')
# !pwd
# Out:
# /content/drive/MyDrive/EM_sensitivity_0430

# %%
# !pip install TorchSisso -q

# CUDA_VISIBLE_DEVICES=0
# !nvidia-smi
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.2 MB/s eta 0:00:00

# %%
from TorchSisso import SissoModel
import numpy as np
import pandas as pd
import sympy
from sympy import symbols

# %%
df_ = pd.read_csv('/content/drive/MyDrive/EM_sensitivity_0430/all.csv')
df_.head()
# Out:
#    connectivity  content  distance  filler  interface        K
# 0           0.0     0.02     0.005     100         10  1.30980
# 1           0.0     0.02     0.005     100         20  1.33020
# 2           0.0     0.02     0.005     100         30  1.35025
# 3           0.0     0.02     0.005     100         40  1.37000
# 4           0.0     0.02     0.005     100         50  1.38940

# %%
df_.shape
# Out:
# (11000, 6)

# %%
# 极低贯通率
X = df_.iloc[6001:8001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[6001:8001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.22483372688293457  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20703 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[3001:5001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[3001:5001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.013163566589355469  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20702 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[1001:3001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[1001:3001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.02023768424987793  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20612 ************************************************
#
# ...

# %%
# 极低贯通率0
X = df_.iloc[0:1000, :-1].values  # All rows, all columns except the last one
y = df_.iloc[0:1000, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
# Out:
#       Target  connectivity  content  distanc  filler  interface
# 995  1.70745           0.0      0.1     0.05   400.0       10.0
# 996  1.70870           0.0      0.1     0.05   400.0       20.0
# 997  1.70945           0.0      0.1     0.05   400.0       30.0
# 998  1.71010           0.0      0.1     0.05   400.0       40.0
# 999  1.71065           0.0      0.1     0.05   400.0       50.0

# %%
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 62 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.22970890998840332  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 9916 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[1001:2001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[1001:2001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.0068209171295166016  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20612 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[2001:3001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[2001:3001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.0076580047607421875  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20702 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[3001:4001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[3001:4001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.007186174392700195  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20702 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[4001:5001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[4001:5001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.006832122802734375  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20702 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[5001:6001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[5001:6001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.0067138671875  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20702 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[6001:7001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[6001:7001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.006833791732788086  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20703 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[7001:8001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[7001:8001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.0066699981689453125  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20703 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[8001:9001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[8001:9001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.006484270095825195  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20703 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[9001:10001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[9001:10001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.006674289703369141  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20614 ************************************************
#
# ...

# %%
# 极低贯通率
X = df_.iloc[10001:11001, :-1].values  # All rows, all columns except the last one
y = df_.iloc[10001:11001, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 62 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.005533933639526367  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 9916 ************************************************
#
# ...

# %%
df.tail()
# Out:
#       Target  connectivity  content  distanc  filler  interface
# 994  32.3315           1.0      0.1     0.05   400.0       10.0
# 995  32.5315           1.0      0.1     0.05   400.0       20.0
# 996  32.7315           1.0      0.1     0.05   400.0       30.0
# 997  32.9315           1.0      0.1     0.05   400.0       40.0
# 998  33.1315           1.0      0.1     0.05   400.0       50.0

# %%
df.head()
# Out:
#    Target  connectivity  content  distanc  filler  interface
# 0  1.8231           1.0     0.02    0.005   100.0       20.0
# 1  1.8631           1.0     0.02    0.005   100.0       30.0
# 2  1.9031           1.0     0.02    0.005   100.0       40.0
# 3  1.9431           1.0     0.02    0.005   100.0       50.0
# 4  3.3831           1.0     0.02    0.005   200.0       10.0

# %%
# 极低贯通率
X = df_.iloc[8001:, :-1].values  # All rows, all columns except the last one
y = df_.iloc[8001:, -1].values   # All rows, only the last column (target)
# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)
df.tail()
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 90 ************************************************
#
# ************************************************ Time taken to create the space is::: 0.2474353313446045  Seconds...************************************************
#
# ************************************************ Starting 2 level of feature expansion...************************************************
#
# ************************************************ 2 Feature Expansion Completed with feature space size::: 20614 ************************************************
#
# ...

# %%
#全部数据测试
X = df_.iloc[:, :-1].values  # All rows, all columns except the last one
y = df_.iloc[:, -1].values   # All rows, only the last column (target)

# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]

# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)

# Display the dataframe (optional)
print(df.head())
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse,equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
#     Target  connectivity  content  distanc  filler  interface
# 0  1.30980           0.0     0.02    0.005   100.0       10.0
# 1  1.33020           0.0     0.02    0.005   100.0       20.0
# 2  1.35025           0.0     0.02    0.005   100.0       30.0
# 3  1.37000           0.0     0.02    0.005   100.0       40.0
# 4  1.38940           0.0     0.02    0.005   100.0       50.0
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 85 ************************************************
#
# ...

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/EM_sensitivity_0430/summary_linear_K.csv')
df_1.head()
# Out:
#    connectivity  content  distance  filler  interface        K
# 0            10     0.02     0.005     100         10  1.36155
# 1            10     0.02     0.005     100         20  1.38415
# 2            10     0.02     0.005     100         30  1.40650
# 3            10     0.02     0.005     100         40  1.42835
# 4            10     0.02     0.005     100         50  1.45010

# %%
X = df_1.iloc[:, :-1].values  # All rows, all columns except the last one
y = df_1.iloc[:, -1].values   # All rows, only the last column (target)

# Assign column names for the features
cols = ["connectivity","content","distanc","filler","interface"]
# Insert the target variable into the dataframe at the beginning
df = pd.DataFrame(X, columns=cols)
df.insert(0, 'Target', y)

# Display the dataframe (optional)
print(df.head())
operators = ['+','-','*','/','exp','ln','sin','cos','pow(2)','pow(0.5)','sqrt','tanh']
rmse, equation,r2,_ = SissoModel(df,operators,n_expansion=3,n_term=3,k=20,use_gpu=False).fit()
# Out:
#     Target  connectivity  content  distanc  filler  interface
# 0  1.36155          10.0     0.02    0.005   100.0       10.0
# 1  1.38415          10.0     0.02    0.005   100.0       20.0
# 2  1.40650          10.0     0.02    0.005   100.0       30.0
# 3  1.42835          10.0     0.02    0.005   100.0       40.0
# 4  1.45010          10.0     0.02    0.005   100.0       50.0
# ************************************************ Starting Feature Space Construction in cpu ************************************************
#
#
#
# ************************************************ Starting 1 level of feature expansion...************************************************
#
# ************************************************ 1 Feature Expansion Completed with feature space size::: 85 ************************************************
#
# ...

# %%
import torch

# %%
# create SISSO model object with relevant user-defined inputs
sm = SissoModel(df = df, #Takes the dataframe as input with first variable as target variable
                operators = operators, #Takes the user-defined operators to perform the feature engineering
                n_expansion = 3, #Defines the number of feature expansions need to be considered
                n_term = 1, #Defines the number of terms in the final equation
                k = 20, #Defines the number of SIS features to be screened for $L_0$ regularization
                initial_screening = "spearman", #Defines the feature screening option for high dimensional and 1-quantile_value defines
                                                                          #the features within this quantile range should be kept for feature expansion.
                use_gpu = False, #Defines the flag whether to consider GPU or not (For efficient computation we consider using GPU only for $L_0$ Regularization.
                dimensionality = ['u1','u2','u3'], #Defines the units of the feature variables in string representation which later converted into sympy format to do the                                                         meaningful feature construction.
                relational_units = [(symbols('u1')*symbols('u2'),symbols('u3'))], #Defines the list of tuples where each tuple represents the relational transformation.
                output_dim = (symbols('u1')*symbols('u1')), #Defines the units of the target variable which helps in narrowing down the space for Regularization.
                custom_unary_functions = [('cos', '-sin', 'exp', 'pow(2)'), ('tanh', 'pow(2)','sin')], #list of tuples (Note only torch supported functions can be customized)
                custom_binary_functions = [
                                          {
                                              'functions1': ['pow(2)'],  # Function to apply on var1 (X1)
                                              'functions2': ['sin'],  # No function to apply on var2 (X2)
                                              'operation': torch.add,  # Operation to apply between var1 and var2
                                              'final_functions': []  # Final function to apply to the result of addition
                                          }
                                      ]
#List of dicts where transformations of variables and operation is provided.. (For example the given code above gives sin(x2) + X^2)

                )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-dcd49b874394> in <cell line: 0>()
#       1 # create SISSO model object with relevant user-defined inputs
# ----> 2 sm = SissoModel(df = df, #Takes the dataframe as input with first variable as target variable
#       3                 operators = operators, #Takes the user-defined operators to perform the feature engineering
#       4                 n_expansion = 3, #Defines the number of feature expansions need to be considered
#       5                 n_term = 1, #Defines the number of terms in the final equation
#
# TypeError: SissoModel.__init__() got an unexpected keyword argument 'df'

# %%
# Run the SISSO algorithm to get the interpretable model with the highest accuracy
rmse, equation, r2,_ = sm.fit()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from TorchSisso import FeatureSpaceConstruction
import torch
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/EM_sensitivity_0430/summary_linear_K.csv')
df.head()
X = df.drop('K', axis=1)
y = df['K']

# %%
# 回归任务，标签为撞击感度和爆速。100epoch

arguments = [
    '--data_path', '/content/drive/MyDrive/EM_sensitivity_0430/reg_IS_DV.csv',
    '--dataset_type', 'regression',
    '--metric', 'r2',
    '--extra_metrics', 'mse','rmse','mae',
    '--features_path', '/content/drive/MyDrive/EM_sensitivity_0430/descriptor_08.csv',
    '--save_dir', '/content/drive/MyDrive/EM_sensitivity_0430/reg_IS_DV_100_epoch',
    '--epochs', '100',
    '--save_smiles_splits'
]

args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-da1faf97-4067-43e7-8680-2fb638e2579f.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
# ...

# %%
# 分类任务，标签为撞击感度和爆速。100epoch

arguments = [
    '--data_path', '/content/drive/MyDrive/EM_sensitivity_0430/reg_IS_DV_V2.csv',
    '--dataset_type', 'classification',
    '--metric', 'accuracy',
    '--extra_metrics', 'auc','f1','binary_cross_entropy','prc-auc','mcc',
    # '--num_folds','1',
    '--features_path', '/content/drive/MyDrive/EM_sensitivity_0430/descriptor_08.csv',
    '--save_dir', '/content/drive/MyDrive/EM_sensitivity_0430/reg_IS_DV_100_epoch',
    '--epochs', '100',
    # '--save_smiles_splits'
]
args = chemprop.args.TrainArgs().parse_args(arguments)

# %%
# 分类任务，标签为撞击感度和密度。100epoch

arguments = [
    '--data_path', '/content/drive/MyDrive/EM_sensitivity_0430/cla_IS_density_V2.csv',
    '--dataset_type', 'classification',
    '--metric', 'accuracy',
    '--extra_metrics', 'auc','f1','binary_cross_entropy','prc-auc','mcc',
    # '--num_folds','1',
    '--features_path', '/content/drive/MyDrive/EM_sensitivity_0430/descriptor_08.csv',
    '--save_dir', '/content/drive/MyDrive/EM_sensitivity_0430/cla_IS_density_100_epoch',
    '--epochs', '100',
    # '--save_smiles_splits'
]
args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-db6b6b1b-f9d9-49a5-9226-8a81eceac7eb.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
# ...

# %%
# 分类任务，标签为撞击感度。100epoch

arguments = [
    '--data_path', '/content/drive/MyDrive/EM_sensitivity_0430/cla_IS_V2.csv',
    '--dataset_type', 'classification',
    '--metric', 'accuracy',
    '--extra_metrics', 'auc','f1','binary_cross_entropy','prc-auc','mcc',
    # '--num_folds','1',
    '--features_path', '/content/drive/MyDrive/EM_sensitivity_0430/descriptor_08.csv',
    '--save_dir', '/content/drive/MyDrive/EM_sensitivity_0430/cla_IS_100_epoch',
    '--epochs', '100',
    # '--save_smiles_splits'
]
args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-db6b6b1b-f9d9-49a5-9226-8a81eceac7eb.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
# ...

# %%
# 分类任务，标签为爆速。100epoch

arguments = [
    '--data_path', '/content/drive/MyDrive/EM_sensitivity_0430/cla_DV_V2.csv',
    '--dataset_type', 'classification',
    '--metric', 'accuracy',
    '--extra_metrics', 'auc','f1','binary_cross_entropy','prc-auc','mcc',
    # '--num_folds','1',
    '--features_path', '/content/drive/MyDrive/EM_sensitivity_0430/descriptor_08.csv',
    '--save_dir', '/content/drive/MyDrive/EM_sensitivity_0430/cla_DV_100_epoch',
    '--epochs', '100',
    # '--save_smiles_splits'
]
args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-db6b6b1b-f9d9-49a5-9226-8a81eceac7eb.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
# ...

# %%
# 分类任务，标签为密度。100epoch

arguments = [
    '--data_path', '/content/drive/MyDrive/EM_sensitivity_0430/cla_density_V2.csv',
    '--dataset_type', 'classification',
    '--metric', 'accuracy',
    '--extra_metrics', 'auc','f1','binary_cross_entropy','prc-auc','mcc',
    # '--num_folds','1',
    '--features_path', '/content/drive/MyDrive/EM_sensitivity_0430/descriptor_08.csv',
    '--save_dir', '/content/drive/MyDrive/EM_sensitivity_0430/cla_density_100_epoch',
    '--epochs', '100',
    # '--save_smiles_splits'
]
args = chemprop.args.TrainArgs().parse_args(arguments)
mean_score, std_score = chemprop.train.cross_validate(args=args, train_func=chemprop.train.run_training)
# Out:
# Command line
# python /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-db6b6b1b-f9d9-49a5-9226-8a81eceac7eb.json
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
# ...
